# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques47Voting%20Eligibility%20(Ternary%20Operator)(Method).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter age: "))
status = "Eligible" if age >= 18 else "Not Eligible"
print(status)
