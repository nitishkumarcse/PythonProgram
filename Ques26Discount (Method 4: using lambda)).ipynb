# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques26Discount%20(Method%204%3A%20using%20lambda)).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter price: "))
discount = float(input("Enter discount %: "))

final_price = (lambda p, d: p - p * d / 100)(price, discount)
print("Final price after discount:", final_price)
