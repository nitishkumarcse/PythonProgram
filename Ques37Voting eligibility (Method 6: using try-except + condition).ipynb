# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques37Voting%20eligibility%20(Method%206%3A%20using%20try-except%20%2B%20condition).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
    age = int(input("Enter age: "))
    if age >= 18:
        print("Eligible")
    else:
        print("Not Eligible")
except:
    print("Invalid input")
