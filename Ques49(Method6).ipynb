# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques49(Method6).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter N: "))
# Generate list in one line and join as a string
evens = [str(x) for x in range(1, n + 1) if x % 2 == 0]
print("Even numbers list:", ", ".join(evens))
