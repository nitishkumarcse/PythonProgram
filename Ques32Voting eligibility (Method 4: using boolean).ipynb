# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques32Voting%20eligibility%20(Method%204%3A%20using%20boolean).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter age: "))

eligible = age >= 18
print("Eligible" if eligible else "Not Eligible")
