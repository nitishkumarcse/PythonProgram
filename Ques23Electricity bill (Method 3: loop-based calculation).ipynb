# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques23Electricity%20bill%20(Method%203%3A%20loop-based%20calculation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
units = int(input("Enter units: "))
bill = 0

for i in range(1, units + 1):
    if i <= 100:
        bill += 5
    elif i <= 200:
        bill += 7
    else:
        bill += 10

print("Total bill amount:", bill)
