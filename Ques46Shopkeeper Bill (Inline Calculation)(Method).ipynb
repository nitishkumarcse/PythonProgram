# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques46Shopkeeper%20Bill%20(Inline%20Calculation)(Method).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = float(input("Enter price: "))
disc = float(input("Enter discount percentage: "))

# Calculate final price directly
final_total = price * (1 - disc / 100)

print(f"Final price after discount: {final_total}")
