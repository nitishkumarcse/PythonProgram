# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques17Voting%20eligibility%20(Method%202%3A%20ternary%20operator).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = int(input("Enter age: "))

print("Eligible" if age >= 18 else "Not Eligible")
