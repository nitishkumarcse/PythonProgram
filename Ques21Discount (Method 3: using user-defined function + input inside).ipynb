# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques21Discount%20(Method%203%3A%20using%20user-defined%20function%20%2B%20input%20inside).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def discount_calc():
    price = float(input("Enter price: "))
    discount = float(input("Enter discount %: "))

    final = price - price * discount / 100
    print("Final price after discount:", final)

discount_calc()
