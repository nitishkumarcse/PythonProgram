# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques25Simple%20Interest%20(Method%203%3A%20lambda%20function).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = float(input("Enter P: "))
r = float(input("Enter R: "))
t = float(input("Enter T: "))

si = lambda p, r, t: (p * r * t) / 100
print("Simple Interest:", si(p, r, t))
