# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques44Print%20Even%20Numbers%20(Loop%20with%20Condition)(Method).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter N: "))
print(f"Even numbers up to {n}:")

for i in range(1, n + 1):
    if i % 2 == 0:
        print(i, end=" ")
