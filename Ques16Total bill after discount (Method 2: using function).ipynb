# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques16Total%20bill%20after%20discount%20(Method%202%3A%20using%20function).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_discount(price, discount):
    return price * (1 - discount / 100)

price = float(input("Enter price: "))
discount = float(input("Enter discount percentage: "))

print("Final price after discount:", calculate_discount(price, discount))
