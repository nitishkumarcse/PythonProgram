# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques39Print%20Even%20Numbers%201%20to%20N(Method%206).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter N: "))
print(f"Even numbers between 1 and {n}:")

# Start at 2, go up to n+1, increment by 2
for i in range(2, n + 1, 2):
    print(i, end=" ")
