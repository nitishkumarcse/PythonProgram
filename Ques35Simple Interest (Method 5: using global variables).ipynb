# %% [markdown]
# <a href="https://colab.research.google.com/github/nitishkumarcse/PythonProgram/blob/main/Ques35Simple%20Interest%20(Method%205%3A%20using%20global%20variables).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = float(input("Enter P: "))
r = float(input("Enter R: "))
t = float(input("Enter T: "))

def calculate_si():
    global p, r, t
    return (p * r * t) / 100

print("Simple Interest:", calculate_si())
